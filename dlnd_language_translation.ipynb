# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    source_id_text = []
    for source_sentence in (source_text.split("\n")):
        source_sentence_id = []
        for word in (source_sentence.split(" ")):
            if word in source_vocab_to_int.keys():
                source_sentence_id.append(source_vocab_to_int[word])
            else:
                source_sentence_id.append(source_vocab_to_int['<UNK>'])
        source_id_text.append(source_sentence_id)
    print (source_text)
    print (source_id_text)
    
    
    target_id_text = []
    for target_sentence in target_text.split("\n"):
        target_sentence_id = []
        for word in target_sentence.split(" "):
            if word in target_vocab_to_int.keys():
                target_sentence_id.append(target_vocab_to_int[word])
            else:
                target_sentence_id.append(target_vocab_to_int['<UNK>'])
        target_sentence_id.append(target_vocab_to_int['<EOS>'])
        target_id_text.append(target_sentence_id)        
    print(target_text)
    print(target_id_text)

    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# [[11, 23, 10, 28, 7, 4, 30, 26, 17, 13, 10, 18, 29, 9, 6], [25, 21, 14, 10, 22, 32, 4, 20, 26, 17, 13, 10, 22, 15, 29, 24, 6], [5, 10, 22, 7, 4, 19, 26, 17, 13, 10, 22, 31, 29, 16, 6], [25, 21, 14, 10, 28, 12, 4, 16, 26, 17, 13, 10, 8, 29, 27, 6]]
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# [[9, 24, 18, 25, 15, 10, 4, 29, 28, 27, 30, 18, 17, 23, 11, 7, 1], [13, 32, 18, 33, 26, 23, 19, 28, 27, 30, 8, 14, 23, 31, 7, 1], [5, 18, 33, 15, 23, 16, 28, 27, 30, 18, 33, 6, 23, 21, 7, 1], [13, 32, 18, 25, 20, 23, 21, 28, 27, 30, 12, 26, 23, 22, 7, 1]]
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    input = tf.placeholder(tf.int32, (None,None), 
                           name="input")
    targets = tf.placeholder(tf.int32, (None,None), 
                             name="target")
    learning_rate = tf.placeholder(tf.float32,
                                   name="learning_rate")
    keep_probability = tf.placeholder(tf.float32, 
                                      name="keep_prob")
    target_sequence_length = tf.placeholder(tf.int32, (None, ), 
                                            name="target_sequence_length")
    max_target_sequence_length = tf.reduce_max(target_sequence_length,
                                               name="max_target_sequence_length")
    source_sequence_length = tf.placeholder(tf.int32, (None, ), 
                                            name="source_sequence_length")
    
    return (input, targets, learning_rate, keep_probability, target_sequence_length, 
max_target_sequence_length, source_sequence_length)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    #remove last data <EOS>
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    #append <GO>
    Preprocessed_target_data = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
    
#     print (target_data)
#     print (target_vocab_to_int)
#     print (batch_size)
#     print (Preprocessed_target_data)
    return Preprocessed_target_data

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
#     embed the encoder input
    embed = tf.contrib.layers.embed_sequence(rnn_inputs, source_vocab_size, encoding_embedding_size)


#     defined the single leyer of cells 
    def lstm_cell():
        BasicCell = tf.contrib.rnn.BasicLSTMCell(rnn_size)
        return tf.contrib.rnn.DropoutWrapper(
             BasicCell, 
             input_keep_prob=keep_prob, # used keep_prob for input layer
             output_keep_prob=1.0, # do not use keep_prob for output layer
             state_keep_prob=1.0, # do not use keep_prob for state layer
             variational_recurrent=False,
             input_size=None,
             dtype=None,
             seed=None)
#     stacked the layers
    stacked_lstm = tf.contrib.rnn.MultiRNNCell([lstm_cell() for _ in range(num_layers)])
        
    return tf.nn.dynamic_rnn(stacked_lstm, 
                             embed,
                             sequence_length=source_sequence_length,
                             initial_state=None, 
                             dtype=tf.float32,
                             parallel_iterations=None,
                             swap_memory=False,
                             time_major=False,
                             scope=None)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    TrainingHelper = tf.contrib.seq2seq.TrainingHelper(
           inputs=dec_embed_input,
           sequence_length=target_sequence_length,
           time_major=False,
           name=None)
    
    
    BasicDecoder = tf.contrib.seq2seq.BasicDecoder(cell=dec_cell,
                                                   helper=TrainingHelper,
                                                   initial_state=encoder_state,
                                                   output_layer=output_layer) # None
    
    
    DynamicDecode, _ = tf.contrib.seq2seq.dynamic_decode(decoder=BasicDecoder,
                                                      output_time_major=False,
                                                      impute_finished=False,
                                                      maximum_iterations=max_summary_length,
                                                      parallel_iterations=32,
                                                      swap_memory=False,
                                                      scope=None)


    return DynamicDecode



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    GreedyEmbeddingHelper = tf.contrib.seq2seq.GreedyEmbeddingHelper(
        embedding=dec_embeddings,
        start_tokens=[start_of_sequence_id] * batch_size,
        end_token=end_of_sequence_id)
    
    
    BasicDecoder = tf.contrib.seq2seq.BasicDecoder(cell=dec_cell,
                                                   helper=GreedyEmbeddingHelper,
                                                   initial_state=encoder_state,
                                                   output_layer=output_layer) # None
    
    
    DynamicDecode, _ = tf.contrib.seq2seq.dynamic_decode(decoder=BasicDecoder,
                                                      output_time_major=False,
                                                      impute_finished=False,
                                                      maximum_iterations=None,
                                                      parallel_iterations=32,
                                                      swap_memory=False,
                                                      scope=None)

    return DynamicDecode



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    
#     Here I could not use 'tf.contrib.layers.embed_sequence' 
#     since I need the dec_embeddings parameter further in the code
#     dec_embed_input = tf.contrib.layers.embed_sequence(
#         dec_input, target_vocab_size, decoding_embedding_size)

#     so I used a previous code using 'tf.nn.embedding_lookup'
    dec_embeddings = tf.Variable(
        tf.random_uniform((target_vocab_size, decoding_embedding_size), -1, 1))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)


#     defined the single leyer of cells 
    def lstm_cell():
        BasicCell = tf.contrib.rnn.BasicLSTMCell(rnn_size)
        return tf.contrib.rnn.DropoutWrapper(
             BasicCell, 
             input_keep_prob=keep_prob, # used keep_prob for input layer
             output_keep_prob=1.0, # do not use keep_prob for output layer
             state_keep_prob=1.0, # do not use keep_prob for state layer
             variational_recurrent=False,
             input_size=None,
             dtype=None,
             seed=None)
#     stacked the layers
    dec_cell = tf.contrib.rnn.MultiRNNCell([lstm_cell() for _ in range(num_layers)])

#     add a fully connected layer
    from tensorflow.python.layers.core import Dense
    output_layer = Dense(units=target_vocab_size, 
                         kernel_initializer=tf.truncated_normal_initializer(mean = 0.0, stddev=0.1)) 
    
#     start and end IDs
    start_of_sequence_id = target_vocab_to_int['<GO>']
    end_of_sequence_id = target_vocab_to_int['<EOS>']
    
    with tf.variable_scope("training") as training_scope:
        training_output = decoding_layer_train(encoder_state, 
                             dec_cell, 
                             dec_embed_input, 
                             target_sequence_length, 
                             max_target_sequence_length, 
                             output_layer, 
                             keep_prob)
        
    with tf.variable_scope("training", reuse=True) as inference_scope:
        inference_output= decoding_layer_infer(encoder_state, 
                             dec_cell, 
                             dec_embeddings, 
                             start_of_sequence_id, 
                             end_of_sequence_id, 
                             max_target_sequence_length, 
                             target_vocab_size, 
                             output_layer, 
                             batch_size, 
                             keep_prob)

    
    return training_output, inference_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
#     Encode
    enc_output, enc_state = encoding_layer(
        input_data, 
        rnn_size, 
        num_layers, 
        keep_prob,  
        source_sequence_length,
        source_vocab_size, 
        enc_embedding_size)
    
#     Process
    dec_input = process_decoder_input(
        target_data, 
        target_vocab_to_int,
        batch_size)
    
#     Decode
    training_output, inference_output = decoding_layer(
        dec_input, 
        enc_state, 
        target_sequence_length, 
        max_target_sentence_length, 
        rnn_size, num_layers, 
        target_vocab_to_int, 
        target_vocab_size, 
        batch_size, 
        keep_prob, 
        dec_embedding_size)
    
    
    return training_output, inference_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 10
# Batch Size
batch_size = 256
# RNN Size
rnn_size = 256
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 256
decoding_embedding_size = 256
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.7
display_step = 10

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   10/538 - Train Accuracy: 0.2660, Validation Accuracy: 0.3551, Loss: 3.5612
# Epoch   0 Batch   20/538 - Train Accuracy: 0.3503, Validation Accuracy: 0.4013, Loss: 2.7235
# Epoch   0 Batch   30/538 - Train Accuracy: 0.3471, Validation Accuracy: 0.4199, Loss: 2.4500
# Epoch   0 Batch   40/538 - Train Accuracy: 0.4135, Validation Accuracy: 0.4338, Loss: 1.9166
# Epoch   0 Batch   50/538 - Train Accuracy: 0.3611, Validation Accuracy: 0.4339, Loss: 1.8021
# Epoch   0 Batch   60/538 - Train Accuracy: 0.3826, Validation Accuracy: 0.4581, Loss: 1.6073
# Epoch   0 Batch   70/538 - Train Accuracy: 0.4157, Validation Accuracy: 0.4577, Loss: 1.3905
# Epoch   0 Batch   80/538 - Train Accuracy: 0.4012, Validation Accuracy: 0.4647, Loss: 1.3525
# Epoch   0 Batch   90/538 - Train Accuracy: 0.4232, Validation Accuracy: 0.4519, Loss: 1.1917
# Epoch   0 Batch  100/538 - Train Accuracy: 0.4406, Validation Accuracy: 0.4872, Loss: 1.0982
# Epoch   0 Batch  110/538 - Train Accuracy: 0.4225, Validation Accuracy: 0.4954, Loss: 1.0813
# Epoch   0 Batch  120/538 - Train Accuracy: 0.4482, Validation Accuracy: 0.4970, Loss: 0.9659
# Epoch   0 Batch  130/538 - Train Accuracy: 0.4875, Validation Accuracy: 0.5119, Loss: 0.8977
# Epoch   0 Batch  140/538 - Train Accuracy: 0.4547, Validation Accuracy: 0.5266, Loss: 0.9586
# Epoch   0 Batch  150/538 - Train Accuracy: 0.5180, Validation Accuracy: 0.5353, Loss: 0.8645
# Epoch   0 Batch  160/538 - Train Accuracy: 0.5277, Validation Accuracy: 0.5494, Loss: 0.7902
# Epoch   0 Batch  170/538 - Train Accuracy: 0.5502, Validation Accuracy: 0.5664, Loss: 0.7792
# Epoch   0 Batch  180/538 - Train Accuracy: 0.5926, Validation Accuracy: 0.5714, Loss: 0.7667
# Epoch   0 Batch  190/538 - Train Accuracy: 0.5312, Validation Accuracy: 0.5554, Loss: 0.7757
# Epoch   0 Batch  200/538 - Train Accuracy: 0.5646, Validation Accuracy: 0.5749, Loss: 0.7307
# Epoch   0 Batch  210/538 - Train Accuracy: 0.5549, Validation Accuracy: 0.5826, Loss: 0.7074
# Epoch   0 Batch  220/538 - Train Accuracy: 0.5459, Validation Accuracy: 0.5941, Loss: 0.6787
# Epoch   0 Batch  230/538 - Train Accuracy: 0.5627, Validation Accuracy: 0.5884, Loss: 0.6967
# Epoch   0 Batch  240/538 - Train Accuracy: 0.5691, Validation Accuracy: 0.5977, Loss: 0.6986
# Epoch   0 Batch  250/538 - Train Accuracy: 0.5727, Validation Accuracy: 0.5991, Loss: 0.6573
# Epoch   0 Batch  260/538 - Train Accuracy: 0.5872, Validation Accuracy: 0.6014, Loss: 0.6431
# Epoch   0 Batch  270/538 - Train Accuracy: 0.5721, Validation Accuracy: 0.5835, Loss: 0.6349
# Epoch   0 Batch  280/538 - Train Accuracy: 0.6317, Validation Accuracy: 0.6129, Loss: 0.5924
# Epoch   0 Batch  290/538 - Train Accuracy: 0.5840, Validation Accuracy: 0.6149, Loss: 0.6088
# Epoch   0 Batch  300/538 - Train Accuracy: 0.6200, Validation Accuracy: 0.6163, Loss: 0.5904
# Epoch   0 Batch  310/538 - Train Accuracy: 0.6076, Validation Accuracy: 0.6156, Loss: 0.5899
# Epoch   0 Batch  320/538 - Train Accuracy: 0.6233, Validation Accuracy: 0.6120, Loss: 0.5717
# Epoch   0 Batch  330/538 - Train Accuracy: 0.6235, Validation Accuracy: 0.6200, Loss: 0.5477
# Epoch   0 Batch  340/538 - Train Accuracy: 0.6070, Validation Accuracy: 0.6117, Loss: 0.5862
# Epoch   0 Batch  350/538 - Train Accuracy: 0.6280, Validation Accuracy: 0.6309, Loss: 0.5589
# Epoch   0 Batch  360/538 - Train Accuracy: 0.6258, Validation Accuracy: 0.6177, Loss: 0.5629
# Epoch   0 Batch  370/538 - Train Accuracy: 0.6248, Validation Accuracy: 0.6403, Loss: 0.5631
# Epoch   0 Batch  380/538 - Train Accuracy: 0.6119, Validation Accuracy: 0.6468, Loss: 0.5300
# Epoch   0 Batch  390/538 - Train Accuracy: 0.6574, Validation Accuracy: 0.6460, Loss: 0.5199
# Epoch   0 Batch  400/538 - Train Accuracy: 0.6347, Validation Accuracy: 0.6495, Loss: 0.5128
# Epoch   0 Batch  410/538 - Train Accuracy: 0.6229, Validation Accuracy: 0.6506, Loss: 0.5275
# Epoch   0 Batch  420/538 - Train Accuracy: 0.6600, Validation Accuracy: 0.6630, Loss: 0.5029
# Epoch   0 Batch  430/538 - Train Accuracy: 0.6527, Validation Accuracy: 0.6580, Loss: 0.4986
# Epoch   0 Batch  440/538 - Train Accuracy: 0.6521, Validation Accuracy: 0.6635, Loss: 0.5181
# Epoch   0 Batch  450/538 - Train Accuracy: 0.6849, Validation Accuracy: 0.6758, Loss: 0.4827
# Epoch   0 Batch  460/538 - Train Accuracy: 0.6490, Validation Accuracy: 0.6681, Loss: 0.4498
# Epoch   0 Batch  470/538 - Train Accuracy: 0.6730, Validation Accuracy: 0.6855, Loss: 0.4457
# Epoch   0 Batch  480/538 - Train Accuracy: 0.6559, Validation Accuracy: 0.6706, Loss: 0.4405
# Epoch   0 Batch  490/538 - Train Accuracy: 0.6648, Validation Accuracy: 0.6662, Loss: 0.4437
# Epoch   0 Batch  500/538 - Train Accuracy: 0.6884, Validation Accuracy: 0.6802, Loss: 0.3931
# Epoch   0 Batch  510/538 - Train Accuracy: 0.6646, Validation Accuracy: 0.6861, Loss: 0.4061
# Epoch   0 Batch  520/538 - Train Accuracy: 0.6691, Validation Accuracy: 0.6914, Loss: 0.4190
# Epoch   0 Batch  530/538 - Train Accuracy: 0.6936, Validation Accuracy: 0.6845, Loss: 0.4150
# Epoch   1 Batch   10/538 - Train Accuracy: 0.6916, Validation Accuracy: 0.6863, Loss: 0.4035
# Epoch   1 Batch   20/538 - Train Accuracy: 0.7210, Validation Accuracy: 0.7021, Loss: 0.3744
# Epoch   1 Batch   30/538 - Train Accuracy: 0.7170, Validation Accuracy: 0.6955, Loss: 0.3816
# Epoch   1 Batch   40/538 - Train Accuracy: 0.7607, Validation Accuracy: 0.7092, Loss: 0.3146
# Epoch   1 Batch   50/538 - Train Accuracy: 0.7500, Validation Accuracy: 0.7156, Loss: 0.3411
# Epoch   1 Batch   60/538 - Train Accuracy: 0.7367, Validation Accuracy: 0.7260, Loss: 0.3298
# Epoch   1 Batch   70/538 - Train Accuracy: 0.7472, Validation Accuracy: 0.7333, Loss: 0.3089
# Epoch   1 Batch   80/538 - Train Accuracy: 0.7465, Validation Accuracy: 0.7370, Loss: 0.3276
# Epoch   1 Batch   90/538 - Train Accuracy: 0.7645, Validation Accuracy: 0.7575, Loss: 0.3081
# Epoch   1 Batch  100/538 - Train Accuracy: 0.7959, Validation Accuracy: 0.7619, Loss: 0.2831
# Epoch   1 Batch  110/538 - Train Accuracy: 0.7732, Validation Accuracy: 0.7667, Loss: 0.2927
# Epoch   1 Batch  120/538 - Train Accuracy: 0.7990, Validation Accuracy: 0.7765, Loss: 0.2578
# Epoch   1 Batch  130/538 - Train Accuracy: 0.8105, Validation Accuracy: 0.7901, Loss: 0.2481
# Epoch   1 Batch  140/538 - Train Accuracy: 0.7945, Validation Accuracy: 0.8223, Loss: 0.2708
# Epoch   1 Batch  150/538 - Train Accuracy: 0.8318, Validation Accuracy: 0.8015, Loss: 0.2477
# Epoch   1 Batch  160/538 - Train Accuracy: 0.8203, Validation Accuracy: 0.8246, Loss: 0.2313
# Epoch   1 Batch  170/538 - Train Accuracy: 0.8238, Validation Accuracy: 0.8288, Loss: 0.2314
# Epoch   1 Batch  180/538 - Train Accuracy: 0.8620, Validation Accuracy: 0.8404, Loss: 0.2217
# Epoch   1 Batch  190/538 - Train Accuracy: 0.8512, Validation Accuracy: 0.8267, Loss: 0.2300
# Epoch   1 Batch  200/538 - Train Accuracy: 0.8426, Validation Accuracy: 0.8374, Loss: 0.2013
# Epoch   1 Batch  210/538 - Train Accuracy: 0.8460, Validation Accuracy: 0.8503, Loss: 0.1959
# Epoch   1 Batch  220/538 - Train Accuracy: 0.8343, Validation Accuracy: 0.8418, Loss: 0.1887
# Epoch   1 Batch  230/538 - Train Accuracy: 0.8883, Validation Accuracy: 0.8377, Loss: 0.1895
# Epoch   1 Batch  240/538 - Train Accuracy: 0.8551, Validation Accuracy: 0.8581, Loss: 0.1874
# Epoch   1 Batch  250/538 - Train Accuracy: 0.8822, Validation Accuracy: 0.8622, Loss: 0.1720
# Epoch   1 Batch  260/538 - Train Accuracy: 0.8432, Validation Accuracy: 0.8645, Loss: 0.1650
# Epoch   1 Batch  270/538 - Train Accuracy: 0.8920, Validation Accuracy: 0.8675, Loss: 0.1563
# Epoch   1 Batch  280/538 - Train Accuracy: 0.9025, Validation Accuracy: 0.8704, Loss: 0.1379
# Epoch   1 Batch  290/538 - Train Accuracy: 0.8955, Validation Accuracy: 0.8881, Loss: 0.1375
# Epoch   1 Batch  300/538 - Train Accuracy: 0.8785, Validation Accuracy: 0.8924, Loss: 0.1417
# Epoch   1 Batch  310/538 - Train Accuracy: 0.9207, Validation Accuracy: 0.8871, Loss: 0.1303
# Epoch   1 Batch  320/538 - Train Accuracy: 0.9038, Validation Accuracy: 0.8892, Loss: 0.1192
# Epoch   1 Batch  330/538 - Train Accuracy: 0.9029, Validation Accuracy: 0.8702, Loss: 0.1167
# Epoch   1 Batch  340/538 - Train Accuracy: 0.8889, Validation Accuracy: 0.8991, Loss: 0.1227
# Epoch   1 Batch  350/538 - Train Accuracy: 0.8955, Validation Accuracy: 0.9047, Loss: 0.1221
# Epoch   1 Batch  360/538 - Train Accuracy: 0.9049, Validation Accuracy: 0.9071, Loss: 0.1123
# Epoch   1 Batch  370/538 - Train Accuracy: 0.9000, Validation Accuracy: 0.8977, Loss: 0.1134
# Epoch   1 Batch  380/538 - Train Accuracy: 0.9037, Validation Accuracy: 0.9109, Loss: 0.1038
# Epoch   1 Batch  390/538 - Train Accuracy: 0.9347, Validation Accuracy: 0.9073, Loss: 0.0900
# Epoch   1 Batch  400/538 - Train Accuracy: 0.9044, Validation Accuracy: 0.9059, Loss: 0.1032
# Epoch   1 Batch  410/538 - Train Accuracy: 0.9092, Validation Accuracy: 0.9048, Loss: 0.1060
# Epoch   1 Batch  420/538 - Train Accuracy: 0.9316, Validation Accuracy: 0.8990, Loss: 0.0922
# Epoch   1 Batch  430/538 - Train Accuracy: 0.8902, Validation Accuracy: 0.9077, Loss: 0.0895
# Epoch   1 Batch  440/538 - Train Accuracy: 0.9092, Validation Accuracy: 0.9039, Loss: 0.0993
# Epoch   1 Batch  450/538 - Train Accuracy: 0.9081, Validation Accuracy: 0.9020, Loss: 0.1018
# Epoch   1 Batch  460/538 - Train Accuracy: 0.8858, Validation Accuracy: 0.9082, Loss: 0.0937
# Epoch   1 Batch  470/538 - Train Accuracy: 0.9262, Validation Accuracy: 0.9027, Loss: 0.0821
# Epoch   1 Batch  480/538 - Train Accuracy: 0.9327, Validation Accuracy: 0.9025, Loss: 0.0757
# Epoch   1 Batch  490/538 - Train Accuracy: 0.9271, Validation Accuracy: 0.9180, Loss: 0.0780
# Epoch   1 Batch  500/538 - Train Accuracy: 0.9347, Validation Accuracy: 0.9155, Loss: 0.0638
# Epoch   1 Batch  510/538 - Train Accuracy: 0.9237, Validation Accuracy: 0.9181, Loss: 0.0706
# Epoch   1 Batch  520/538 - Train Accuracy: 0.9086, Validation Accuracy: 0.9268, Loss: 0.0765
# Epoch   1 Batch  530/538 - Train Accuracy: 0.8939, Validation Accuracy: 0.9254, Loss: 0.0836
# Epoch   2 Batch   10/538 - Train Accuracy: 0.9193, Validation Accuracy: 0.9247, Loss: 0.0726
# Epoch   2 Batch   20/538 - Train Accuracy: 0.9232, Validation Accuracy: 0.9265, Loss: 0.0702
# Epoch   2 Batch   30/538 - Train Accuracy: 0.9105, Validation Accuracy: 0.9176, Loss: 0.0793
# Epoch   2 Batch   40/538 - Train Accuracy: 0.9199, Validation Accuracy: 0.9171, Loss: 0.0589
# Epoch   2 Batch   50/538 - Train Accuracy: 0.9262, Validation Accuracy: 0.9318, Loss: 0.0616
# Epoch   2 Batch   60/538 - Train Accuracy: 0.9412, Validation Accuracy: 0.9279, Loss: 0.0633
# Epoch   2 Batch   70/538 - Train Accuracy: 0.9252, Validation Accuracy: 0.9284, Loss: 0.0667
# Epoch   2 Batch   80/538 - Train Accuracy: 0.9209, Validation Accuracy: 0.9180, Loss: 0.0686
# Epoch   2 Batch   90/538 - Train Accuracy: 0.9280, Validation Accuracy: 0.9181, Loss: 0.0727
# Epoch   2 Batch  100/538 - Train Accuracy: 0.9430, Validation Accuracy: 0.9249, Loss: 0.0568
# Epoch   2 Batch  110/538 - Train Accuracy: 0.9148, Validation Accuracy: 0.9277, Loss: 0.0600
# Epoch   2 Batch  120/538 - Train Accuracy: 0.9625, Validation Accuracy: 0.9345, Loss: 0.0488
# Epoch   2 Batch  130/538 - Train Accuracy: 0.9284, Validation Accuracy: 0.9391, Loss: 0.0539
# Epoch   2 Batch  140/538 - Train Accuracy: 0.9105, Validation Accuracy: 0.9336, Loss: 0.0723
# Epoch   2 Batch  150/538 - Train Accuracy: 0.9398, Validation Accuracy: 0.9332, Loss: 0.0565
# Epoch   2 Batch  160/538 - Train Accuracy: 0.9010, Validation Accuracy: 0.9245, Loss: 0.0568
# Epoch   2 Batch  170/538 - Train Accuracy: 0.9330, Validation Accuracy: 0.9345, Loss: 0.0560
# Epoch   2 Batch  180/538 - Train Accuracy: 0.9366, Validation Accuracy: 0.9339, Loss: 0.0555
# Epoch   2 Batch  190/538 - Train Accuracy: 0.9297, Validation Accuracy: 0.9286, Loss: 0.0745
# Epoch   2 Batch  200/538 - Train Accuracy: 0.9430, Validation Accuracy: 0.9389, Loss: 0.0492
# Epoch   2 Batch  210/538 - Train Accuracy: 0.9141, Validation Accuracy: 0.9400, Loss: 0.0564
# Epoch   2 Batch  220/538 - Train Accuracy: 0.9249, Validation Accuracy: 0.9380, Loss: 0.0571
# Epoch   2 Batch  230/538 - Train Accuracy: 0.9375, Validation Accuracy: 0.9398, Loss: 0.0508
# Epoch   2 Batch  240/538 - Train Accuracy: 0.9385, Validation Accuracy: 0.9329, Loss: 0.0535
# Epoch   2 Batch  250/538 - Train Accuracy: 0.9486, Validation Accuracy: 0.9364, Loss: 0.0475
# Epoch   2 Batch  260/538 - Train Accuracy: 0.9016, Validation Accuracy: 0.9412, Loss: 0.0567
# Epoch   2 Batch  270/538 - Train Accuracy: 0.9461, Validation Accuracy: 0.9482, Loss: 0.0459
# Epoch   2 Batch  280/538 - Train Accuracy: 0.9611, Validation Accuracy: 0.9329, Loss: 0.0477
# Epoch   2 Batch  290/538 - Train Accuracy: 0.9613, Validation Accuracy: 0.9412, Loss: 0.0408
# Epoch   2 Batch  300/538 - Train Accuracy: 0.9312, Validation Accuracy: 0.9457, Loss: 0.0547
# Epoch   2 Batch  310/538 - Train Accuracy: 0.9504, Validation Accuracy: 0.9565, Loss: 0.0515
# Epoch   2 Batch  320/538 - Train Accuracy: 0.9472, Validation Accuracy: 0.9522, Loss: 0.0419
# Epoch   2 Batch  330/538 - Train Accuracy: 0.9611, Validation Accuracy: 0.9624, Loss: 0.0425
# Epoch   2 Batch  340/538 - Train Accuracy: 0.9434, Validation Accuracy: 0.9560, Loss: 0.0495
# Epoch   2 Batch  350/538 - Train Accuracy: 0.9487, Validation Accuracy: 0.9494, Loss: 0.0496
# Epoch   2 Batch  360/538 - Train Accuracy: 0.9527, Validation Accuracy: 0.9498, Loss: 0.0423
# Epoch   2 Batch  370/538 - Train Accuracy: 0.9537, Validation Accuracy: 0.9538, Loss: 0.0427
# Epoch   2 Batch  380/538 - Train Accuracy: 0.9570, Validation Accuracy: 0.9560, Loss: 0.0442
# Epoch   2 Batch  390/538 - Train Accuracy: 0.9581, Validation Accuracy: 0.9506, Loss: 0.0372
# Epoch   2 Batch  400/538 - Train Accuracy: 0.9524, Validation Accuracy: 0.9529, Loss: 0.0451
# Epoch   2 Batch  410/538 - Train Accuracy: 0.9463, Validation Accuracy: 0.9608, Loss: 0.0487
# Epoch   2 Batch  420/538 - Train Accuracy: 0.9607, Validation Accuracy: 0.9375, Loss: 0.0421
# Epoch   2 Batch  430/538 - Train Accuracy: 0.9307, Validation Accuracy: 0.9473, Loss: 0.0429
# Epoch   2 Batch  440/538 - Train Accuracy: 0.9502, Validation Accuracy: 0.9444, Loss: 0.0470
# Epoch   2 Batch  450/538 - Train Accuracy: 0.9362, Validation Accuracy: 0.9531, Loss: 0.0508
# Epoch   2 Batch  460/538 - Train Accuracy: 0.9295, Validation Accuracy: 0.9537, Loss: 0.0440
# Epoch   2 Batch  470/538 - Train Accuracy: 0.9626, Validation Accuracy: 0.9577, Loss: 0.0397
# Epoch   2 Batch  480/538 - Train Accuracy: 0.9615, Validation Accuracy: 0.9531, Loss: 0.0350
# Epoch   2 Batch  490/538 - Train Accuracy: 0.9507, Validation Accuracy: 0.9597, Loss: 0.0423
# Epoch   2 Batch  500/538 - Train Accuracy: 0.9602, Validation Accuracy: 0.9588, Loss: 0.0340
# Epoch   2 Batch  510/538 - Train Accuracy: 0.9608, Validation Accuracy: 0.9574, Loss: 0.0400
# Epoch   2 Batch  520/538 - Train Accuracy: 0.9633, Validation Accuracy: 0.9542, Loss: 0.0405
# Epoch   2 Batch  530/538 - Train Accuracy: 0.9242, Validation Accuracy: 0.9640, Loss: 0.0461
# Epoch   3 Batch   10/538 - Train Accuracy: 0.9434, Validation Accuracy: 0.9554, Loss: 0.0405
# Epoch   3 Batch   20/538 - Train Accuracy: 0.9580, Validation Accuracy: 0.9677, Loss: 0.0421
# Epoch   3 Batch   30/538 - Train Accuracy: 0.9340, Validation Accuracy: 0.9513, Loss: 0.0452
# Epoch   3 Batch   40/538 - Train Accuracy: 0.9593, Validation Accuracy: 0.9588, Loss: 0.0302
# Epoch   3 Batch   50/538 - Train Accuracy: 0.9553, Validation Accuracy: 0.9657, Loss: 0.0344
# Epoch   3 Batch   60/538 - Train Accuracy: 0.9598, Validation Accuracy: 0.9542, Loss: 0.0381
# Epoch   3 Batch   70/538 - Train Accuracy: 0.9676, Validation Accuracy: 0.9640, Loss: 0.0339
# Epoch   3 Batch   80/538 - Train Accuracy: 0.9488, Validation Accuracy: 0.9590, Loss: 0.0349
# Epoch   3 Batch   90/538 - Train Accuracy: 0.9581, Validation Accuracy: 0.9654, Loss: 0.0414
# Epoch   3 Batch  100/538 - Train Accuracy: 0.9602, Validation Accuracy: 0.9595, Loss: 0.0298
# Epoch   3 Batch  110/538 - Train Accuracy: 0.9572, Validation Accuracy: 0.9718, Loss: 0.0309
# Epoch   3 Batch  120/538 - Train Accuracy: 0.9717, Validation Accuracy: 0.9640, Loss: 0.0246
# Epoch   3 Batch  130/538 - Train Accuracy: 0.9611, Validation Accuracy: 0.9677, Loss: 0.0317
# Epoch   3 Batch  140/538 - Train Accuracy: 0.9422, Validation Accuracy: 0.9554, Loss: 0.0455
# Epoch   3 Batch  150/538 - Train Accuracy: 0.9672, Validation Accuracy: 0.9515, Loss: 0.0296
# Epoch   3 Batch  160/538 - Train Accuracy: 0.9487, Validation Accuracy: 0.9483, Loss: 0.0323
# Epoch   3 Batch  170/538 - Train Accuracy: 0.9552, Validation Accuracy: 0.9668, Loss: 0.0336
# Epoch   3 Batch  180/538 - Train Accuracy: 0.9608, Validation Accuracy: 0.9522, Loss: 0.0325
# Epoch   3 Batch  190/538 - Train Accuracy: 0.9539, Validation Accuracy: 0.9561, Loss: 0.0457
# Epoch   3 Batch  200/538 - Train Accuracy: 0.9738, Validation Accuracy: 0.9592, Loss: 0.0282
# Epoch   3 Batch  210/538 - Train Accuracy: 0.9490, Validation Accuracy: 0.9474, Loss: 0.0337
# Epoch   3 Batch  220/538 - Train Accuracy: 0.9459, Validation Accuracy: 0.9535, Loss: 0.0362
# Epoch   3 Batch  230/538 - Train Accuracy: 0.9582, Validation Accuracy: 0.9586, Loss: 0.0314
# Epoch   3 Batch  240/538 - Train Accuracy: 0.9559, Validation Accuracy: 0.9696, Loss: 0.0373
# Epoch   3 Batch  250/538 - Train Accuracy: 0.9621, Validation Accuracy: 0.9574, Loss: 0.0299
# Epoch   3 Batch  260/538 - Train Accuracy: 0.9397, Validation Accuracy: 0.9636, Loss: 0.0402
# Epoch   3 Batch  270/538 - Train Accuracy: 0.9680, Validation Accuracy: 0.9577, Loss: 0.0275
# Epoch   3 Batch  280/538 - Train Accuracy: 0.9758, Validation Accuracy: 0.9696, Loss: 0.0259
# Epoch   3 Batch  290/538 - Train Accuracy: 0.9801, Validation Accuracy: 0.9673, Loss: 0.0255
# Epoch   3 Batch  300/538 - Train Accuracy: 0.9526, Validation Accuracy: 0.9719, Loss: 0.0337
# Epoch   3 Batch  310/538 - Train Accuracy: 0.9625, Validation Accuracy: 0.9702, Loss: 0.0375
# Epoch   3 Batch  320/538 - Train Accuracy: 0.9637, Validation Accuracy: 0.9672, Loss: 0.0266
# Epoch   3 Batch  330/538 - Train Accuracy: 0.9717, Validation Accuracy: 0.9672, Loss: 0.0283
# Epoch   3 Batch  340/538 - Train Accuracy: 0.9623, Validation Accuracy: 0.9627, Loss: 0.0315
# Epoch   3 Batch  350/538 - Train Accuracy: 0.9693, Validation Accuracy: 0.9670, Loss: 0.0314
# Epoch   3 Batch  360/538 - Train Accuracy: 0.9705, Validation Accuracy: 0.9675, Loss: 0.0279
# Epoch   3 Batch  370/538 - Train Accuracy: 0.9650, Validation Accuracy: 0.9727, Loss: 0.0293
# Epoch   3 Batch  380/538 - Train Accuracy: 0.9707, Validation Accuracy: 0.9654, Loss: 0.0305
# Epoch   3 Batch  390/538 - Train Accuracy: 0.9652, Validation Accuracy: 0.9632, Loss: 0.0240
# Epoch   3 Batch  400/538 - Train Accuracy: 0.9701, Validation Accuracy: 0.9668, Loss: 0.0304
# Epoch   3 Batch  410/538 - Train Accuracy: 0.9746, Validation Accuracy: 0.9732, Loss: 0.0308
# Epoch   3 Batch  420/538 - Train Accuracy: 0.9682, Validation Accuracy: 0.9648, Loss: 0.0284
# Epoch   3 Batch  430/538 - Train Accuracy: 0.9457, Validation Accuracy: 0.9769, Loss: 0.0286
# Epoch   3 Batch  440/538 - Train Accuracy: 0.9705, Validation Accuracy: 0.9670, Loss: 0.0290
# Epoch   3 Batch  450/538 - Train Accuracy: 0.9511, Validation Accuracy: 0.9721, Loss: 0.0387
# Epoch   3 Batch  460/538 - Train Accuracy: 0.9611, Validation Accuracy: 0.9716, Loss: 0.0297
# Epoch   3 Batch  470/538 - Train Accuracy: 0.9645, Validation Accuracy: 0.9766, Loss: 0.0286
# Epoch   3 Batch  480/538 - Train Accuracy: 0.9840, Validation Accuracy: 0.9652, Loss: 0.0252
# Epoch   3 Batch  490/538 - Train Accuracy: 0.9647, Validation Accuracy: 0.9739, Loss: 0.0253
# Epoch   3 Batch  500/538 - Train Accuracy: 0.9817, Validation Accuracy: 0.9695, Loss: 0.0199
# Epoch   3 Batch  510/538 - Train Accuracy: 0.9708, Validation Accuracy: 0.9689, Loss: 0.0236
# Epoch   3 Batch  520/538 - Train Accuracy: 0.9767, Validation Accuracy: 0.9778, Loss: 0.0296
# Epoch   3 Batch  530/538 - Train Accuracy: 0.9625, Validation Accuracy: 0.9769, Loss: 0.0303
# Epoch   4 Batch   10/538 - Train Accuracy: 0.9660, Validation Accuracy: 0.9686, Loss: 0.0264
# Epoch   4 Batch   20/538 - Train Accuracy: 0.9680, Validation Accuracy: 0.9730, Loss: 0.0271
# Epoch   4 Batch   30/538 - Train Accuracy: 0.9459, Validation Accuracy: 0.9764, Loss: 0.0289
# Epoch   4 Batch   40/538 - Train Accuracy: 0.9657, Validation Accuracy: 0.9693, Loss: 0.0196
# Epoch   4 Batch   50/538 - Train Accuracy: 0.9682, Validation Accuracy: 0.9778, Loss: 0.0250
# Epoch   4 Batch   60/538 - Train Accuracy: 0.9654, Validation Accuracy: 0.9735, Loss: 0.0260
# Epoch   4 Batch   70/538 - Train Accuracy: 0.9743, Validation Accuracy: 0.9775, Loss: 0.0243
# Epoch   4 Batch   80/538 - Train Accuracy: 0.9678, Validation Accuracy: 0.9735, Loss: 0.0241
# Epoch   4 Batch   90/538 - Train Accuracy: 0.9730, Validation Accuracy: 0.9647, Loss: 0.0324
# Epoch   4 Batch  100/538 - Train Accuracy: 0.9805, Validation Accuracy: 0.9638, Loss: 0.0211
# Epoch   4 Batch  110/538 - Train Accuracy: 0.9652, Validation Accuracy: 0.9695, Loss: 0.0260
# Epoch   4 Batch  120/538 - Train Accuracy: 0.9748, Validation Accuracy: 0.9700, Loss: 0.0190
# Epoch   4 Batch  130/538 - Train Accuracy: 0.9634, Validation Accuracy: 0.9679, Loss: 0.0231
# Epoch   4 Batch  140/538 - Train Accuracy: 0.9586, Validation Accuracy: 0.9585, Loss: 0.0305
# Epoch   4 Batch  150/538 - Train Accuracy: 0.9689, Validation Accuracy: 0.9618, Loss: 0.0221
# Epoch   4 Batch  160/538 - Train Accuracy: 0.9628, Validation Accuracy: 0.9611, Loss: 0.0229
# Epoch   4 Batch  170/538 - Train Accuracy: 0.9622, Validation Accuracy: 0.9691, Loss: 0.0256
# Epoch   4 Batch  180/538 - Train Accuracy: 0.9617, Validation Accuracy: 0.9622, Loss: 0.0259
# Epoch   4 Batch  190/538 - Train Accuracy: 0.9593, Validation Accuracy: 0.9686, Loss: 0.0326
# Epoch   4 Batch  200/538 - Train Accuracy: 0.9836, Validation Accuracy: 0.9693, Loss: 0.0182
# Epoch   4 Batch  210/538 - Train Accuracy: 0.9634, Validation Accuracy: 0.9703, Loss: 0.0305
# Epoch   4 Batch  220/538 - Train Accuracy: 0.9593, Validation Accuracy: 0.9675, Loss: 0.0265
# Epoch   4 Batch  230/538 - Train Accuracy: 0.9729, Validation Accuracy: 0.9666, Loss: 0.0199
# Epoch   4 Batch  240/538 - Train Accuracy: 0.9672, Validation Accuracy: 0.9688, Loss: 0.0267
# Epoch   4 Batch  250/538 - Train Accuracy: 0.9762, Validation Accuracy: 0.9666, Loss: 0.0236
# Epoch   4 Batch  260/538 - Train Accuracy: 0.9541, Validation Accuracy: 0.9561, Loss: 0.0276
# Epoch   4 Batch  270/538 - Train Accuracy: 0.9754, Validation Accuracy: 0.9611, Loss: 0.0199
# Epoch   4 Batch  280/538 - Train Accuracy: 0.9756, Validation Accuracy: 0.9707, Loss: 0.0189
# Epoch   4 Batch  290/538 - Train Accuracy: 0.9842, Validation Accuracy: 0.9760, Loss: 0.0194
# Epoch   4 Batch  300/538 - Train Accuracy: 0.9769, Validation Accuracy: 0.9734, Loss: 0.0259
# Epoch   4 Batch  310/538 - Train Accuracy: 0.9797, Validation Accuracy: 0.9689, Loss: 0.0259
# Epoch   4 Batch  320/538 - Train Accuracy: 0.9810, Validation Accuracy: 0.9670, Loss: 0.0204
# Epoch   4 Batch  330/538 - Train Accuracy: 0.9749, Validation Accuracy: 0.9712, Loss: 0.0186
# Epoch   4 Batch  340/538 - Train Accuracy: 0.9588, Validation Accuracy: 0.9682, Loss: 0.0227
# Epoch   4 Batch  350/538 - Train Accuracy: 0.9661, Validation Accuracy: 0.9725, Loss: 0.0242
# Epoch   4 Batch  360/538 - Train Accuracy: 0.9756, Validation Accuracy: 0.9700, Loss: 0.0181
# Epoch   4 Batch  370/538 - Train Accuracy: 0.9641, Validation Accuracy: 0.9688, Loss: 0.0224
# Epoch   4 Batch  380/538 - Train Accuracy: 0.9824, Validation Accuracy: 0.9689, Loss: 0.0192
# Epoch   4 Batch  390/538 - Train Accuracy: 0.9825, Validation Accuracy: 0.9709, Loss: 0.0160
# Epoch   4 Batch  400/538 - Train Accuracy: 0.9734, Validation Accuracy: 0.9673, Loss: 0.0231
# Epoch   4 Batch  410/538 - Train Accuracy: 0.9746, Validation Accuracy: 0.9609, Loss: 0.0223
# Epoch   4 Batch  420/538 - Train Accuracy: 0.9746, Validation Accuracy: 0.9732, Loss: 0.0230
# Epoch   4 Batch  430/538 - Train Accuracy: 0.9566, Validation Accuracy: 0.9799, Loss: 0.0223
# Epoch   4 Batch  440/538 - Train Accuracy: 0.9742, Validation Accuracy: 0.9734, Loss: 0.0250
# Epoch   4 Batch  450/538 - Train Accuracy: 0.9591, Validation Accuracy: 0.9799, Loss: 0.0304
# Epoch   4 Batch  460/538 - Train Accuracy: 0.9701, Validation Accuracy: 0.9712, Loss: 0.0225
# Epoch   4 Batch  470/538 - Train Accuracy: 0.9641, Validation Accuracy: 0.9664, Loss: 0.0199
# Epoch   4 Batch  480/538 - Train Accuracy: 0.9838, Validation Accuracy: 0.9741, Loss: 0.0189
# Epoch   4 Batch  490/538 - Train Accuracy: 0.9701, Validation Accuracy: 0.9728, Loss: 0.0215
# Epoch   4 Batch  500/538 - Train Accuracy: 0.9817, Validation Accuracy: 0.9743, Loss: 0.0149
# Epoch   4 Batch  510/538 - Train Accuracy: 0.9730, Validation Accuracy: 0.9721, Loss: 0.0198
# Epoch   4 Batch  520/538 - Train Accuracy: 0.9742, Validation Accuracy: 0.9691, Loss: 0.0226
# Epoch   4 Batch  530/538 - Train Accuracy: 0.9703, Validation Accuracy: 0.9767, Loss: 0.0261
# Epoch   5 Batch   10/538 - Train Accuracy: 0.9678, Validation Accuracy: 0.9757, Loss: 0.0211
# Epoch   5 Batch   20/538 - Train Accuracy: 0.9695, Validation Accuracy: 0.9672, Loss: 0.0224
# Epoch   5 Batch   30/538 - Train Accuracy: 0.9629, Validation Accuracy: 0.9664, Loss: 0.0218
# Epoch   5 Batch   40/538 - Train Accuracy: 0.9845, Validation Accuracy: 0.9725, Loss: 0.0162
# Epoch   5 Batch   50/538 - Train Accuracy: 0.9725, Validation Accuracy: 0.9686, Loss: 0.0190
# Epoch   5 Batch   60/538 - Train Accuracy: 0.9771, Validation Accuracy: 0.9790, Loss: 0.0221
# Epoch   5 Batch   70/538 - Train Accuracy: 0.9764, Validation Accuracy: 0.9748, Loss: 0.0172
# Epoch   5 Batch   80/538 - Train Accuracy: 0.9762, Validation Accuracy: 0.9819, Loss: 0.0171
# Epoch   5 Batch   90/538 - Train Accuracy: 0.9740, Validation Accuracy: 0.9659, Loss: 0.0238
# Epoch   5 Batch  100/538 - Train Accuracy: 0.9879, Validation Accuracy: 0.9759, Loss: 0.0156
# Epoch   5 Batch  110/538 - Train Accuracy: 0.9752, Validation Accuracy: 0.9705, Loss: 0.0183
# Epoch   5 Batch  120/538 - Train Accuracy: 0.9805, Validation Accuracy: 0.9730, Loss: 0.0126
# Epoch   5 Batch  130/538 - Train Accuracy: 0.9745, Validation Accuracy: 0.9673, Loss: 0.0180
# Epoch   5 Batch  140/538 - Train Accuracy: 0.9711, Validation Accuracy: 0.9730, Loss: 0.0250
# Epoch   5 Batch  150/538 - Train Accuracy: 0.9820, Validation Accuracy: 0.9714, Loss: 0.0164
# Epoch   5 Batch  160/538 - Train Accuracy: 0.9771, Validation Accuracy: 0.9753, Loss: 0.0178
# Epoch   5 Batch  170/538 - Train Accuracy: 0.9775, Validation Accuracy: 0.9750, Loss: 0.0189
# Epoch   5 Batch  180/538 - Train Accuracy: 0.9717, Validation Accuracy: 0.9716, Loss: 0.0184
# Epoch   5 Batch  190/538 - Train Accuracy: 0.9674, Validation Accuracy: 0.9684, Loss: 0.0258
# Epoch   5 Batch  200/538 - Train Accuracy: 0.9803, Validation Accuracy: 0.9712, Loss: 0.0146
# Epoch   5 Batch  210/538 - Train Accuracy: 0.9725, Validation Accuracy: 0.9821, Loss: 0.0203
# Epoch   5 Batch  220/538 - Train Accuracy: 0.9706, Validation Accuracy: 0.9734, Loss: 0.0188
# Epoch   5 Batch  230/538 - Train Accuracy: 0.9738, Validation Accuracy: 0.9806, Loss: 0.0166
# Epoch   5 Batch  240/538 - Train Accuracy: 0.9727, Validation Accuracy: 0.9753, Loss: 0.0210
# Epoch   5 Batch  250/538 - Train Accuracy: 0.9838, Validation Accuracy: 0.9759, Loss: 0.0198
# Epoch   5 Batch  260/538 - Train Accuracy: 0.9667, Validation Accuracy: 0.9764, Loss: 0.0217
# Epoch   5 Batch  270/538 - Train Accuracy: 0.9842, Validation Accuracy: 0.9719, Loss: 0.0180
# Epoch   5 Batch  280/538 - Train Accuracy: 0.9673, Validation Accuracy: 0.9778, Loss: 0.0165
# Epoch   5 Batch  290/538 - Train Accuracy: 0.9879, Validation Accuracy: 0.9753, Loss: 0.0146
# Epoch   5 Batch  300/538 - Train Accuracy: 0.9751, Validation Accuracy: 0.9819, Loss: 0.0194
# Epoch   5 Batch  310/538 - Train Accuracy: 0.9756, Validation Accuracy: 0.9798, Loss: 0.0211
# Epoch   5 Batch  320/538 - Train Accuracy: 0.9807, Validation Accuracy: 0.9769, Loss: 0.0158
# Epoch   5 Batch  330/538 - Train Accuracy: 0.9773, Validation Accuracy: 0.9668, Loss: 0.0175
# Epoch   5 Batch  340/538 - Train Accuracy: 0.9846, Validation Accuracy: 0.9716, Loss: 0.0164
# Epoch   5 Batch  350/538 - Train Accuracy: 0.9741, Validation Accuracy: 0.9696, Loss: 0.0191
# Epoch   5 Batch  360/538 - Train Accuracy: 0.9760, Validation Accuracy: 0.9776, Loss: 0.0172
# Epoch   5 Batch  370/538 - Train Accuracy: 0.9709, Validation Accuracy: 0.9735, Loss: 0.0176
# Epoch   5 Batch  380/538 - Train Accuracy: 0.9924, Validation Accuracy: 0.9739, Loss: 0.0157
# Epoch   5 Batch  390/538 - Train Accuracy: 0.9812, Validation Accuracy: 0.9700, Loss: 0.0136
# Epoch   5 Batch  400/538 - Train Accuracy: 0.9725, Validation Accuracy: 0.9757, Loss: 0.0165
# Epoch   5 Batch  410/538 - Train Accuracy: 0.9896, Validation Accuracy: 0.9691, Loss: 0.0147
# Epoch   5 Batch  420/538 - Train Accuracy: 0.9682, Validation Accuracy: 0.9751, Loss: 0.0182
# Epoch   5 Batch  430/538 - Train Accuracy: 0.9678, Validation Accuracy: 0.9821, Loss: 0.0180
# Epoch   5 Batch  440/538 - Train Accuracy: 0.9855, Validation Accuracy: 0.9698, Loss: 0.0160
# Epoch   5 Batch  450/538 - Train Accuracy: 0.9706, Validation Accuracy: 0.9719, Loss: 0.0223
# Epoch   5 Batch  460/538 - Train Accuracy: 0.9702, Validation Accuracy: 0.9782, Loss: 0.0187
# Epoch   5 Batch  470/538 - Train Accuracy: 0.9767, Validation Accuracy: 0.9794, Loss: 0.0166
# Epoch   5 Batch  480/538 - Train Accuracy: 0.9838, Validation Accuracy: 0.9679, Loss: 0.0141
# Epoch   5 Batch  490/538 - Train Accuracy: 0.9695, Validation Accuracy: 0.9727, Loss: 0.0164
# Epoch   5 Batch  500/538 - Train Accuracy: 0.9849, Validation Accuracy: 0.9821, Loss: 0.0125
# Epoch   5 Batch  510/538 - Train Accuracy: 0.9829, Validation Accuracy: 0.9828, Loss: 0.0156
# Epoch   5 Batch  520/538 - Train Accuracy: 0.9787, Validation Accuracy: 0.9778, Loss: 0.0205
# Epoch   5 Batch  530/538 - Train Accuracy: 0.9707, Validation Accuracy: 0.9862, Loss: 0.0189
# Epoch   6 Batch   10/538 - Train Accuracy: 0.9742, Validation Accuracy: 0.9714, Loss: 0.0176
# Epoch   6 Batch   20/538 - Train Accuracy: 0.9784, Validation Accuracy: 0.9759, Loss: 0.0193
# Epoch   6 Batch   30/538 - Train Accuracy: 0.9641, Validation Accuracy: 0.9693, Loss: 0.0157
# Epoch   6 Batch   40/538 - Train Accuracy: 0.9865, Validation Accuracy: 0.9709, Loss: 0.0110
# Epoch   6 Batch   50/538 - Train Accuracy: 0.9713, Validation Accuracy: 0.9794, Loss: 0.0145
# Epoch   6 Batch   60/538 - Train Accuracy: 0.9789, Validation Accuracy: 0.9746, Loss: 0.0181
# Epoch   6 Batch   70/538 - Train Accuracy: 0.9760, Validation Accuracy: 0.9785, Loss: 0.0141
# Epoch   6 Batch   80/538 - Train Accuracy: 0.9844, Validation Accuracy: 0.9721, Loss: 0.0129
# Epoch   6 Batch   90/538 - Train Accuracy: 0.9661, Validation Accuracy: 0.9696, Loss: 0.0200
# Epoch   6 Batch  100/538 - Train Accuracy: 0.9863, Validation Accuracy: 0.9798, Loss: 0.0151
# Epoch   6 Batch  110/538 - Train Accuracy: 0.9775, Validation Accuracy: 0.9771, Loss: 0.0172
# Epoch   6 Batch  120/538 - Train Accuracy: 0.9857, Validation Accuracy: 0.9666, Loss: 0.0115
# Epoch   6 Batch  130/538 - Train Accuracy: 0.9797, Validation Accuracy: 0.9821, Loss: 0.0137
# Epoch   6 Batch  140/538 - Train Accuracy: 0.9747, Validation Accuracy: 0.9831, Loss: 0.0220
# Epoch   6 Batch  150/538 - Train Accuracy: 0.9801, Validation Accuracy: 0.9753, Loss: 0.0141
# Epoch   6 Batch  160/538 - Train Accuracy: 0.9821, Validation Accuracy: 0.9810, Loss: 0.0160
# Epoch   6 Batch  170/538 - Train Accuracy: 0.9710, Validation Accuracy: 0.9728, Loss: 0.0169
# Epoch   6 Batch  180/538 - Train Accuracy: 0.9684, Validation Accuracy: 0.9707, Loss: 0.0148
# Epoch   6 Batch  190/538 - Train Accuracy: 0.9749, Validation Accuracy: 0.9672, Loss: 0.0207
# Epoch   6 Batch  200/538 - Train Accuracy: 0.9793, Validation Accuracy: 0.9723, Loss: 0.0115
# Epoch   6 Batch  210/538 - Train Accuracy: 0.9807, Validation Accuracy: 0.9778, Loss: 0.0186
# Epoch   6 Batch  220/538 - Train Accuracy: 0.9704, Validation Accuracy: 0.9732, Loss: 0.0158
# Epoch   6 Batch  230/538 - Train Accuracy: 0.9809, Validation Accuracy: 0.9705, Loss: 0.0133
# Epoch   6 Batch  240/538 - Train Accuracy: 0.9836, Validation Accuracy: 0.9743, Loss: 0.0148
# Epoch   6 Batch  250/538 - Train Accuracy: 0.9818, Validation Accuracy: 0.9688, Loss: 0.0175
# Epoch   6 Batch  260/538 - Train Accuracy: 0.9676, Validation Accuracy: 0.9705, Loss: 0.0174
# Epoch   6 Batch  270/538 - Train Accuracy: 0.9848, Validation Accuracy: 0.9698, Loss: 0.0139
# Epoch   6 Batch  280/538 - Train Accuracy: 0.9838, Validation Accuracy: 0.9759, Loss: 0.0125
# Epoch   6 Batch  290/538 - Train Accuracy: 0.9865, Validation Accuracy: 0.9775, Loss: 0.0142
# Epoch   6 Batch  300/538 - Train Accuracy: 0.9818, Validation Accuracy: 0.9751, Loss: 0.0161
# Epoch   6 Batch  310/538 - Train Accuracy: 0.9842, Validation Accuracy: 0.9737, Loss: 0.0194
# Epoch   6 Batch  320/538 - Train Accuracy: 0.9834, Validation Accuracy: 0.9679, Loss: 0.0115
# Epoch   6 Batch  330/538 - Train Accuracy: 0.9870, Validation Accuracy: 0.9693, Loss: 0.0123
# Epoch   6 Batch  340/538 - Train Accuracy: 0.9793, Validation Accuracy: 0.9641, Loss: 0.0132
# Epoch   6 Batch  350/538 - Train Accuracy: 0.9764, Validation Accuracy: 0.9773, Loss: 0.0179
# Epoch   6 Batch  360/538 - Train Accuracy: 0.9863, Validation Accuracy: 0.9732, Loss: 0.0140
# Epoch   6 Batch  370/538 - Train Accuracy: 0.9775, Validation Accuracy: 0.9785, Loss: 0.0144
# Epoch   6 Batch  380/538 - Train Accuracy: 0.9873, Validation Accuracy: 0.9776, Loss: 0.0141
# Epoch   6 Batch  390/538 - Train Accuracy: 0.9842, Validation Accuracy: 0.9654, Loss: 0.0130
# Epoch   6 Batch  400/538 - Train Accuracy: 0.9818, Validation Accuracy: 0.9767, Loss: 0.0154
# Epoch   6 Batch  410/538 - Train Accuracy: 0.9820, Validation Accuracy: 0.9702, Loss: 0.0126
# Epoch   6 Batch  420/538 - Train Accuracy: 0.9771, Validation Accuracy: 0.9730, Loss: 0.0164
# Epoch   6 Batch  430/538 - Train Accuracy: 0.9711, Validation Accuracy: 0.9727, Loss: 0.0175
# Epoch   6 Batch  440/538 - Train Accuracy: 0.9830, Validation Accuracy: 0.9792, Loss: 0.0156
# Epoch   6 Batch  450/538 - Train Accuracy: 0.9727, Validation Accuracy: 0.9771, Loss: 0.0185
# Epoch   6 Batch  460/538 - Train Accuracy: 0.9807, Validation Accuracy: 0.9819, Loss: 0.0128
# Epoch   6 Batch  470/538 - Train Accuracy: 0.9747, Validation Accuracy: 0.9778, Loss: 0.0157
# Epoch   6 Batch  480/538 - Train Accuracy: 0.9862, Validation Accuracy: 0.9783, Loss: 0.0122
# Epoch   6 Batch  490/538 - Train Accuracy: 0.9743, Validation Accuracy: 0.9862, Loss: 0.0145
# Epoch   6 Batch  500/538 - Train Accuracy: 0.9925, Validation Accuracy: 0.9705, Loss: 0.0101
# Epoch   6 Batch  510/538 - Train Accuracy: 0.9805, Validation Accuracy: 0.9778, Loss: 0.0145
# Epoch   6 Batch  520/538 - Train Accuracy: 0.9836, Validation Accuracy: 0.9821, Loss: 0.0178
# Epoch   6 Batch  530/538 - Train Accuracy: 0.9738, Validation Accuracy: 0.9790, Loss: 0.0157
# Epoch   7 Batch   10/538 - Train Accuracy: 0.9807, Validation Accuracy: 0.9789, Loss: 0.0146
# Epoch   7 Batch   20/538 - Train Accuracy: 0.9788, Validation Accuracy: 0.9805, Loss: 0.0177
# Epoch   7 Batch   30/538 - Train Accuracy: 0.9715, Validation Accuracy: 0.9700, Loss: 0.0160
# Epoch   7 Batch   40/538 - Train Accuracy: 0.9869, Validation Accuracy: 0.9746, Loss: 0.0098
# Epoch   7 Batch   50/538 - Train Accuracy: 0.9781, Validation Accuracy: 0.9771, Loss: 0.0129
# Epoch   7 Batch   60/538 - Train Accuracy: 0.9723, Validation Accuracy: 0.9830, Loss: 0.0174
# Epoch   7 Batch   70/538 - Train Accuracy: 0.9834, Validation Accuracy: 0.9798, Loss: 0.0115
# Epoch   7 Batch   80/538 - Train Accuracy: 0.9826, Validation Accuracy: 0.9828, Loss: 0.0115
# Epoch   7 Batch   90/538 - Train Accuracy: 0.9747, Validation Accuracy: 0.9783, Loss: 0.0171
# Epoch   7 Batch  100/538 - Train Accuracy: 0.9883, Validation Accuracy: 0.9835, Loss: 0.0109
# Epoch   7 Batch  110/538 - Train Accuracy: 0.9838, Validation Accuracy: 0.9819, Loss: 0.0116
# Epoch   7 Batch  120/538 - Train Accuracy: 0.9883, Validation Accuracy: 0.9806, Loss: 0.0096
# Epoch   7 Batch  130/538 - Train Accuracy: 0.9877, Validation Accuracy: 0.9734, Loss: 0.0137
# Epoch   7 Batch  140/538 - Train Accuracy: 0.9711, Validation Accuracy: 0.9792, Loss: 0.0174
# Epoch   7 Batch  150/538 - Train Accuracy: 0.9818, Validation Accuracy: 0.9775, Loss: 0.0120
# Epoch   7 Batch  160/538 - Train Accuracy: 0.9846, Validation Accuracy: 0.9780, Loss: 0.0139
# Epoch   7 Batch  170/538 - Train Accuracy: 0.9788, Validation Accuracy: 0.9719, Loss: 0.0123
# Epoch   7 Batch  180/538 - Train Accuracy: 0.9784, Validation Accuracy: 0.9716, Loss: 0.0134
# Epoch   7 Batch  190/538 - Train Accuracy: 0.9851, Validation Accuracy: 0.9737, Loss: 0.0180
# Epoch   7 Batch  200/538 - Train Accuracy: 0.9773, Validation Accuracy: 0.9819, Loss: 0.0116
# Epoch   7 Batch  210/538 - Train Accuracy: 0.9866, Validation Accuracy: 0.9849, Loss: 0.0146
# Epoch   7 Batch  220/538 - Train Accuracy: 0.9790, Validation Accuracy: 0.9735, Loss: 0.0143
# Epoch   7 Batch  230/538 - Train Accuracy: 0.9711, Validation Accuracy: 0.9691, Loss: 0.0131
# Epoch   7 Batch  240/538 - Train Accuracy: 0.9799, Validation Accuracy: 0.9760, Loss: 0.0142
# Epoch   7 Batch  250/538 - Train Accuracy: 0.9855, Validation Accuracy: 0.9750, Loss: 0.0128
# Epoch   7 Batch  260/538 - Train Accuracy: 0.9734, Validation Accuracy: 0.9750, Loss: 0.0168
# Epoch   7 Batch  270/538 - Train Accuracy: 0.9855, Validation Accuracy: 0.9746, Loss: 0.0124
# Epoch   7 Batch  280/538 - Train Accuracy: 0.9686, Validation Accuracy: 0.9757, Loss: 0.0108
# Epoch   7 Batch  290/538 - Train Accuracy: 0.9857, Validation Accuracy: 0.9851, Loss: 0.0124
# Epoch   7 Batch  300/538 - Train Accuracy: 0.9782, Validation Accuracy: 0.9842, Loss: 0.0152
# Epoch   7 Batch  310/538 - Train Accuracy: 0.9783, Validation Accuracy: 0.9688, Loss: 0.0162
# Epoch   7 Batch  320/538 - Train Accuracy: 0.9877, Validation Accuracy: 0.9760, Loss: 0.0121
# Epoch   7 Batch  330/538 - Train Accuracy: 0.9855, Validation Accuracy: 0.9698, Loss: 0.0101
# Epoch   7 Batch  340/538 - Train Accuracy: 0.9893, Validation Accuracy: 0.9696, Loss: 0.0128
# Epoch   7 Batch  350/538 - Train Accuracy: 0.9831, Validation Accuracy: 0.9760, Loss: 0.0142
# Epoch   7 Batch  360/538 - Train Accuracy: 0.9871, Validation Accuracy: 0.9782, Loss: 0.0109
# Epoch   7 Batch  370/538 - Train Accuracy: 0.9824, Validation Accuracy: 0.9760, Loss: 0.0094
# Epoch   7 Batch  380/538 - Train Accuracy: 0.9838, Validation Accuracy: 0.9702, Loss: 0.0118
# Epoch   7 Batch  390/538 - Train Accuracy: 0.9881, Validation Accuracy: 0.9735, Loss: 0.0100
# Epoch   7 Batch  400/538 - Train Accuracy: 0.9855, Validation Accuracy: 0.9796, Loss: 0.0124
# Epoch   7 Batch  410/538 - Train Accuracy: 0.9900, Validation Accuracy: 0.9757, Loss: 0.0091
# Epoch   7 Batch  420/538 - Train Accuracy: 0.9744, Validation Accuracy: 0.9796, Loss: 0.0153
# Epoch   7 Batch  430/538 - Train Accuracy: 0.9777, Validation Accuracy: 0.9798, Loss: 0.0130
# Epoch   7 Batch  440/538 - Train Accuracy: 0.9908, Validation Accuracy: 0.9822, Loss: 0.0119
# Epoch   7 Batch  450/538 - Train Accuracy: 0.9676, Validation Accuracy: 0.9805, Loss: 0.0186
# Epoch   7 Batch  460/538 - Train Accuracy: 0.9734, Validation Accuracy: 0.9762, Loss: 0.0130
# Epoch   7 Batch  470/538 - Train Accuracy: 0.9782, Validation Accuracy: 0.9707, Loss: 0.0144
# Epoch   7 Batch  480/538 - Train Accuracy: 0.9872, Validation Accuracy: 0.9767, Loss: 0.0107
# Epoch   7 Batch  490/538 - Train Accuracy: 0.9771, Validation Accuracy: 0.9801, Loss: 0.0114
# Epoch   7 Batch  500/538 - Train Accuracy: 0.9949, Validation Accuracy: 0.9700, Loss: 0.0079
# Epoch   7 Batch  510/538 - Train Accuracy: 0.9864, Validation Accuracy: 0.9782, Loss: 0.0093
# Epoch   7 Batch  520/538 - Train Accuracy: 0.9851, Validation Accuracy: 0.9833, Loss: 0.0177
# Epoch   7 Batch  530/538 - Train Accuracy: 0.9854, Validation Accuracy: 0.9819, Loss: 0.0134
# Epoch   8 Batch   10/538 - Train Accuracy: 0.9820, Validation Accuracy: 0.9805, Loss: 0.0132
# Epoch   8 Batch   20/538 - Train Accuracy: 0.9860, Validation Accuracy: 0.9838, Loss: 0.0154
# Epoch   8 Batch   30/538 - Train Accuracy: 0.9750, Validation Accuracy: 0.9801, Loss: 0.0138
# Epoch   8 Batch   40/538 - Train Accuracy: 0.9854, Validation Accuracy: 0.9766, Loss: 0.0118
# Epoch   8 Batch   50/538 - Train Accuracy: 0.9787, Validation Accuracy: 0.9787, Loss: 0.0119
# Epoch   8 Batch   60/538 - Train Accuracy: 0.9850, Validation Accuracy: 0.9757, Loss: 0.0130
# Epoch   8 Batch   70/538 - Train Accuracy: 0.9834, Validation Accuracy: 0.9775, Loss: 0.0113
# Epoch   8 Batch   80/538 - Train Accuracy: 0.9926, Validation Accuracy: 0.9838, Loss: 0.0095
# Epoch   8 Batch   90/538 - Train Accuracy: 0.9790, Validation Accuracy: 0.9766, Loss: 0.0132
# Epoch   8 Batch  100/538 - Train Accuracy: 0.9906, Validation Accuracy: 0.9796, Loss: 0.0087
# Epoch   8 Batch  110/538 - Train Accuracy: 0.9881, Validation Accuracy: 0.9796, Loss: 0.0124
# Epoch   8 Batch  120/538 - Train Accuracy: 0.9924, Validation Accuracy: 0.9771, Loss: 0.0080
# Epoch   8 Batch  130/538 - Train Accuracy: 0.9829, Validation Accuracy: 0.9750, Loss: 0.0134
# Epoch   8 Batch  140/538 - Train Accuracy: 0.9749, Validation Accuracy: 0.9712, Loss: 0.0149
# Epoch   8 Batch  150/538 - Train Accuracy: 0.9855, Validation Accuracy: 0.9785, Loss: 0.0112
# Epoch   8 Batch  160/538 - Train Accuracy: 0.9784, Validation Accuracy: 0.9759, Loss: 0.0117
# Epoch   8 Batch  170/538 - Train Accuracy: 0.9734, Validation Accuracy: 0.9750, Loss: 0.0117
# Epoch   8 Batch  180/538 - Train Accuracy: 0.9844, Validation Accuracy: 0.9680, Loss: 0.0128
# Epoch   8 Batch  190/538 - Train Accuracy: 0.9794, Validation Accuracy: 0.9801, Loss: 0.0163
# Epoch   8 Batch  200/538 - Train Accuracy: 0.9863, Validation Accuracy: 0.9766, Loss: 0.0077
# Epoch   8 Batch  210/538 - Train Accuracy: 0.9857, Validation Accuracy: 0.9877, Loss: 0.0130
# Epoch   8 Batch  220/538 - Train Accuracy: 0.9784, Validation Accuracy: 0.9764, Loss: 0.0127
# Epoch   8 Batch  230/538 - Train Accuracy: 0.9773, Validation Accuracy: 0.9737, Loss: 0.0116
# Epoch   8 Batch  240/538 - Train Accuracy: 0.9775, Validation Accuracy: 0.9760, Loss: 0.0129
# Epoch   8 Batch  250/538 - Train Accuracy: 0.9869, Validation Accuracy: 0.9764, Loss: 0.0137
# Epoch   8 Batch  260/538 - Train Accuracy: 0.9697, Validation Accuracy: 0.9798, Loss: 0.0135
# Epoch   8 Batch  270/538 - Train Accuracy: 0.9861, Validation Accuracy: 0.9760, Loss: 0.0081
# Epoch   8 Batch  280/538 - Train Accuracy: 0.9888, Validation Accuracy: 0.9769, Loss: 0.0094
# Epoch   8 Batch  290/538 - Train Accuracy: 0.9898, Validation Accuracy: 0.9870, Loss: 0.0098
# Epoch   8 Batch  300/538 - Train Accuracy: 0.9823, Validation Accuracy: 0.9828, Loss: 0.0126
# Epoch   8 Batch  310/538 - Train Accuracy: 0.9826, Validation Accuracy: 0.9778, Loss: 0.0160
# Epoch   8 Batch  320/538 - Train Accuracy: 0.9857, Validation Accuracy: 0.9776, Loss: 0.0085
# Epoch   8 Batch  330/538 - Train Accuracy: 0.9901, Validation Accuracy: 0.9707, Loss: 0.0104
# Epoch   8 Batch  340/538 - Train Accuracy: 0.9828, Validation Accuracy: 0.9767, Loss: 0.0129
# Epoch   8 Batch  350/538 - Train Accuracy: 0.9881, Validation Accuracy: 0.9785, Loss: 0.0114
# Epoch   8 Batch  360/538 - Train Accuracy: 0.9850, Validation Accuracy: 0.9755, Loss: 0.0099
# Epoch   8 Batch  370/538 - Train Accuracy: 0.9828, Validation Accuracy: 0.9767, Loss: 0.0104
# Epoch   8 Batch  380/538 - Train Accuracy: 0.9926, Validation Accuracy: 0.9780, Loss: 0.0107
# Epoch   8 Batch  390/538 - Train Accuracy: 0.9916, Validation Accuracy: 0.9760, Loss: 0.0094
# Epoch   8 Batch  400/538 - Train Accuracy: 0.9849, Validation Accuracy: 0.9798, Loss: 0.0105
# Epoch   8 Batch  410/538 - Train Accuracy: 0.9820, Validation Accuracy: 0.9759, Loss: 0.0111
# Epoch   8 Batch  420/538 - Train Accuracy: 0.9748, Validation Accuracy: 0.9771, Loss: 0.0120
# Epoch   8 Batch  430/538 - Train Accuracy: 0.9852, Validation Accuracy: 0.9767, Loss: 0.0123
# Epoch   8 Batch  440/538 - Train Accuracy: 0.9873, Validation Accuracy: 0.9874, Loss: 0.0137
# Epoch   8 Batch  450/538 - Train Accuracy: 0.9727, Validation Accuracy: 0.9769, Loss: 0.0172
# Epoch   8 Batch  460/538 - Train Accuracy: 0.9764, Validation Accuracy: 0.9775, Loss: 0.0140
# Epoch   8 Batch  470/538 - Train Accuracy: 0.9714, Validation Accuracy: 0.9760, Loss: 0.0125
# Epoch   8 Batch  480/538 - Train Accuracy: 0.9866, Validation Accuracy: 0.9743, Loss: 0.0101
# Epoch   8 Batch  490/538 - Train Accuracy: 0.9860, Validation Accuracy: 0.9757, Loss: 0.0108
# Epoch   8 Batch  500/538 - Train Accuracy: 0.9929, Validation Accuracy: 0.9782, Loss: 0.0083
# Epoch   8 Batch  510/538 - Train Accuracy: 0.9857, Validation Accuracy: 0.9735, Loss: 0.0083
# Epoch   8 Batch  520/538 - Train Accuracy: 0.9820, Validation Accuracy: 0.9773, Loss: 0.0135
# Epoch   8 Batch  530/538 - Train Accuracy: 0.9766, Validation Accuracy: 0.9767, Loss: 0.0129
# Epoch   9 Batch   10/538 - Train Accuracy: 0.9869, Validation Accuracy: 0.9858, Loss: 0.0094
# Epoch   9 Batch   20/538 - Train Accuracy: 0.9812, Validation Accuracy: 0.9854, Loss: 0.0116
# Epoch   9 Batch   30/538 - Train Accuracy: 0.9770, Validation Accuracy: 0.9744, Loss: 0.0127
# Epoch   9 Batch   40/538 - Train Accuracy: 0.9879, Validation Accuracy: 0.9817, Loss: 0.0072
# Epoch   9 Batch   50/538 - Train Accuracy: 0.9848, Validation Accuracy: 0.9806, Loss: 0.0114
# Epoch   9 Batch   60/538 - Train Accuracy: 0.9861, Validation Accuracy: 0.9835, Loss: 0.0096
# Epoch   9 Batch   70/538 - Train Accuracy: 0.9872, Validation Accuracy: 0.9837, Loss: 0.0087
# Epoch   9 Batch   80/538 - Train Accuracy: 0.9943, Validation Accuracy: 0.9847, Loss: 0.0082
# Epoch   9 Batch   90/538 - Train Accuracy: 0.9805, Validation Accuracy: 0.9787, Loss: 0.0143
# Epoch   9 Batch  100/538 - Train Accuracy: 0.9916, Validation Accuracy: 0.9776, Loss: 0.0083
# Epoch   9 Batch  110/538 - Train Accuracy: 0.9777, Validation Accuracy: 0.9789, Loss: 0.0092
# Epoch   9 Batch  120/538 - Train Accuracy: 0.9896, Validation Accuracy: 0.9780, Loss: 0.0073
# Epoch   9 Batch  130/538 - Train Accuracy: 0.9838, Validation Accuracy: 0.9837, Loss: 0.0104
# Epoch   9 Batch  140/538 - Train Accuracy: 0.9846, Validation Accuracy: 0.9805, Loss: 0.0145
# Epoch   9 Batch  150/538 - Train Accuracy: 0.9879, Validation Accuracy: 0.9821, Loss: 0.0114
# Epoch   9 Batch  160/538 - Train Accuracy: 0.9790, Validation Accuracy: 0.9775, Loss: 0.0093
# Epoch   9 Batch  170/538 - Train Accuracy: 0.9814, Validation Accuracy: 0.9787, Loss: 0.0094
# Epoch   9 Batch  180/538 - Train Accuracy: 0.9855, Validation Accuracy: 0.9730, Loss: 0.0118
# Epoch   9 Batch  190/538 - Train Accuracy: 0.9924, Validation Accuracy: 0.9755, Loss: 0.0102
# Epoch   9 Batch  200/538 - Train Accuracy: 0.9889, Validation Accuracy: 0.9744, Loss: 0.0074
# Epoch   9 Batch  210/538 - Train Accuracy: 0.9866, Validation Accuracy: 0.9808, Loss: 0.0122
# Epoch   9 Batch  220/538 - Train Accuracy: 0.9795, Validation Accuracy: 0.9748, Loss: 0.0115
# Epoch   9 Batch  230/538 - Train Accuracy: 0.9779, Validation Accuracy: 0.9691, Loss: 0.0088
# Epoch   9 Batch  240/538 - Train Accuracy: 0.9801, Validation Accuracy: 0.9725, Loss: 0.0106
# Epoch   9 Batch  250/538 - Train Accuracy: 0.9896, Validation Accuracy: 0.9828, Loss: 0.0066
# Epoch   9 Batch  260/538 - Train Accuracy: 0.9818, Validation Accuracy: 0.9762, Loss: 0.0125
# Epoch   9 Batch  270/538 - Train Accuracy: 0.9838, Validation Accuracy: 0.9799, Loss: 0.0094
# Epoch   9 Batch  280/538 - Train Accuracy: 0.9872, Validation Accuracy: 0.9815, Loss: 0.0097
# Epoch   9 Batch  290/538 - Train Accuracy: 0.9875, Validation Accuracy: 0.9826, Loss: 0.0087
# Epoch   9 Batch  300/538 - Train Accuracy: 0.9820, Validation Accuracy: 0.9796, Loss: 0.0115
# Epoch   9 Batch  310/538 - Train Accuracy: 0.9844, Validation Accuracy: 0.9755, Loss: 0.0132
# Epoch   9 Batch  320/538 - Train Accuracy: 0.9823, Validation Accuracy: 0.9810, Loss: 0.0081
# Epoch   9 Batch  330/538 - Train Accuracy: 0.9868, Validation Accuracy: 0.9735, Loss: 0.0131
# Epoch   9 Batch  340/538 - Train Accuracy: 0.9826, Validation Accuracy: 0.9762, Loss: 0.0098
# Epoch   9 Batch  350/538 - Train Accuracy: 0.9872, Validation Accuracy: 0.9757, Loss: 0.0123
# Epoch   9 Batch  360/538 - Train Accuracy: 0.9881, Validation Accuracy: 0.9782, Loss: 0.0093
# Epoch   9 Batch  370/538 - Train Accuracy: 0.9830, Validation Accuracy: 0.9780, Loss: 0.0102
# Epoch   9 Batch  380/538 - Train Accuracy: 0.9900, Validation Accuracy: 0.9725, Loss: 0.0075
# Epoch   9 Batch  390/538 - Train Accuracy: 0.9948, Validation Accuracy: 0.9753, Loss: 0.0070
# Epoch   9 Batch  400/538 - Train Accuracy: 0.9875, Validation Accuracy: 0.9744, Loss: 0.0104
# Epoch   9 Batch  410/538 - Train Accuracy: 0.9881, Validation Accuracy: 0.9735, Loss: 0.0097
# Epoch   9 Batch  420/538 - Train Accuracy: 0.9820, Validation Accuracy: 0.9748, Loss: 0.0106
# Epoch   9 Batch  430/538 - Train Accuracy: 0.9830, Validation Accuracy: 0.9792, Loss: 0.0106
# Epoch   9 Batch  440/538 - Train Accuracy: 0.9926, Validation Accuracy: 0.9773, Loss: 0.0084
# Epoch   9 Batch  450/538 - Train Accuracy: 0.9795, Validation Accuracy: 0.9769, Loss: 0.0170
# Epoch   9 Batch  460/538 - Train Accuracy: 0.9788, Validation Accuracy: 0.9757, Loss: 0.0130
# Epoch   9 Batch  470/538 - Train Accuracy: 0.9877, Validation Accuracy: 0.9760, Loss: 0.0106
# Epoch   9 Batch  480/538 - Train Accuracy: 0.9920, Validation Accuracy: 0.9757, Loss: 0.0088
# Epoch   9 Batch  490/538 - Train Accuracy: 0.9797, Validation Accuracy: 0.9806, Loss: 0.0103
# Epoch   9 Batch  500/538 - Train Accuracy: 0.9924, Validation Accuracy: 0.9751, Loss: 0.0057
# Epoch   9 Batch  510/538 - Train Accuracy: 0.9851, Validation Accuracy: 0.9794, Loss: 0.0095
# Epoch   9 Batch  520/538 - Train Accuracy: 0.9857, Validation Accuracy: 0.9794, Loss: 0.0121
# Epoch   9 Batch  530/538 - Train Accuracy: 0.9873, Validation Accuracy: 0.9821, Loss: 0.0099
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    word_ids = []
    for word in sentence.split():
        word = word.lower()
        if word not in vocab_to_int:
            word = '<UNK>'
        word_ids.append(vocab_to_int[word])
        
    return word_ids


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [69, 15, 179, 33, 153, 107, 176]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [351, 256, 35, 206, 274, 150, 139, 327, 1]
#   French Words: il a vu un vieux camion jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
